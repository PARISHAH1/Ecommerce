# %%
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("abfss://adlscontainer1@parishah16.dfs.core.windows.net/bronze/ecommerce/olist_orders_dataset/2026-04-15/")

display(df)
